# %%
# !pip install git+https://github.com/abhaskumarsinha/Gaussian-LiteSplat.git
# !git clone https://github.com/abhaskumarsinha/Gaussian-LiteSplat.git
# %cd Gaussian-LiteSplat
# Out:
# ...
#   Cloning https://github.com/abhaskumarsinha/Gaussian-LiteSplat.git to /tmp/pip-req-build-2po_q3mf
#   Running command git clone --filter=blob:none --quiet https://github.com/abhaskumarsinha/Gaussian-LiteSplat.git /tmp/pip-req-build-2po_q3mf
#   Resolved https://github.com/abhaskumarsinha/Gaussian-LiteSplat.git to commit 1bef98c6714e072bec831618ece47d47b65430d9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.9 MB/s eta 0:00:0000:010:01
# ...
#   Created wheel for litesplat: filename=litesplat-0.1.0-py3-none-any.whl size=17532 sha256=61fc8245c5193835fc85d4afad9cda4048046c54ce7bdacbc35d6595adc8a801
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vefpro7v/wheels/62/b4/a3/be593a895220c2f2c3e714f5302634a4eed9e015d889c2cdf6
# Successfully built litesplat
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 3.8.0
# ...

# %%
# !python ./scripts/train_colmap.py -h
# Out:
# usage: train_colmap.py [-h] --colmap_scene COLMAP_SCENE --litesplat_scene
#                        LITESPLAT_SCENE --images_dir IMAGES_DIR
#                        [--total_gaussians TOTAL_GAUSSIANS]
#                        [--max_gaussians MAX_GAUSSIANS] [--trainable_focus]
#                        [--trainable_principal] [--trainable_extrinsics]
#                        [--output_h OUTPUT_H] [--output_w OUTPUT_W]
#                        [--output_gaussians OUTPUT_GAUSSIANS]
#                        [--cam_import CAM_IMPORT] [--train_cams TRAIN_CAMS]
#                        [--lr LR] [--weight_decay WEIGHT_DECAY]
#                        [--num_epochs NUM_EPOCHS] [--batch_size BATCH_SIZE]
#                        [--checkpoint CHECKPOINT] [--num_images NUM_IMAGES]
#                        [--cols COLS] [--output_dir OUTPUT_DIR] [--dpi DPI]
#                        [--torch_compile]
#                        [--log_level {DEBUG,INFO,WARNING,ERROR}]
#
# ...

# %%
# !python ./scripts/train_colmap.py --colmap_scene '/kaggle/input/colmap-templering/temple_ring' \
                                  --litesplat_scene '/kaggle/working/litesplat_scene' \
                                  --images_dir '/kaggle/input/colmap-templering/temple_ring/images' \
                                  --output_dir '/kaggle/working/litesplat_output' \
                                  --torch_compile \
                                  --output_h 76 \
                                  --output_w 102 \
                                  --total_gaussians 2200 \
                                  --log_level DEBUG \
                                  --num_epochs 2500
# Out:
# [16:35:29] [INFO] Converting COLMAP scene: /kaggle/input/colmap-templering/temple_ring
# 📁 Valid NeRF scene found at: /kaggle/input/colmap-templering/temple_ring
#   - Using COLMAP data from: /kaggle/input/colmap-templering/temple_ring/sparse/0
#   - Using images from: /kaggle/input/colmap-templering/temple_ring/images
# ✅ Exported:
# → /kaggle/working/litesplat_scene/gaussians.json
# → /kaggle/working/litesplat_scene/camera.json
# [16:35:29] [INFO] Initializing Gaussian parameters...
# 📂 Importing Gaussian scene from: /kaggle/working/litesplat_scene
# 🎲 Randomly sampled 2200 / 7614 Gaussians (seed=None, preserve_order=True).
# [16:35:29] [INFO] Loading camera layers...
# [16:35:31] [INFO] Selected 15 cameras for training: [29, 20, 13, 0, 37, 26, 4, 12, 31, 21, 8, 25, 6, 3, 5]
# [16:35:31] [INFO] y_real shape: (15, 76, 102, 3)  Device: cuda
# [16:35:31] [INFO] Starting training loop...
# ...
